# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create sample data
data = sns.load_dataset("tips")
sns.set_style("darkgrid")

# Customize the color palette
sns.set_palette("rocket")

# Create a bar plot
sns.barplot(x="day", y="total_bill", data=data, ci=None)
plt.title("Customized Bar Plot with Color Palette")
plt.xlabel("Day of the Week")
plt.ylabel("TotalBillAmount($)")
plt.show()
# Out:
# C:\Users\2006n\AppData\Local\Temp\ipykernel_1672\3822908686.py:12: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="day", y="total_bill", data=data, ci=None)
